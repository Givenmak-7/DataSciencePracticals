# %% [markdown]
# <a href="https://colab.research.google.com/github/Givenmak-7/DataSciencePracticals/blob/Pandas_DataFrame_Practical/Pandas_DataFrame_Practical_empty.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas DataFrame practical

# %% [markdown]
# italicized text## CSV / Excel sheet --> DataFrame

# %% [markdown]
# Upload the Excel sheet "sample_sales.xlsx" to your GC Notebook (either by uploading the file or by mounting your Google Drive)

# %%
# enter code here (if necessary)
import pandas as pd
data1 = pd.read_excel('/content/sample_sales.xlsx', sheet_name = 'Sample_Sales_1')

# %% [markdown]
# Create a dataframe **`df1`** from the first sheet of the "sample_sales.xlsx" Excel file.

# %%
# enter code here
df1 = pd.DataFrame(data1)
df1.head()
# Out:
#                               Region                Country        Item Type  \
# 0                             Europe                 Russia  Office Supplies
# 1              Australia and Oceania                 Tuvalu        Baby Food
# 2                                  ~  Sao Tome and Principe           Fruits
# 3  Central America and the Caribbean                Grenada           Cereal
# 4                             Europe                 Russia  Office Supplies
#
#   Order Priority Order Date  Total Cost Total Profit
# 0              L 2014-05-02   933903.84            ~
# 1              H 2010-05-28  1582243.50     951410.5
# 2              C 2014-06-20    56065.84     19525.82
# 3              C 2012-08-22   328376.44    248406.36
# 4              L 2014-05-02   933903.84            ~

# %% [markdown]
# Create a dataframe **`df2`** from the second sheet of the Excel file.
# * Note that this dataset does not have any headings.
# * Add the same headings to this dataframe as in the first sheet:
#
# "Region", "Country", "Item Type", "Order Priority", "Order Date", "Total Cost", "Total Profit"

# %%
# enter code here
header_names = ["Region", "Country", "Item Type", "Order Priority", "Order Date", "Total Cost", "Total Profit"]
data2 = pd.read_excel('/content/sample_sales.xlsx', sheet_name = 'Sample_Sales_2', header = None, names = header_names)
df2 = pd.DataFrame(data2)
df2.head()
# Out:
#                          Region  Country  Item Type Order Priority  \
# 0                        Europe   Monaco  Baby Food              H
# 1         Australia and Oceania   Samoa   Cosmetics              H
# 2                        Europe    Spain  Household              L
# 3  Middle East and North Africa  Lebanon    Clothes              L
# 4  Middle East and North Africa     Iran  Cosmetics              H
#
#             Order Date  Total Cost  Total Profit
# 0  2012-05-29 00:00:00  1373243.88     825738.04
# 1  2013-07-20 00:00:00  2542187.82    1678540.98
# 2  2012-10-21 00:00:00  2267963.02     747939.49
# 3           2012-31-09   282562.56     579000.96
# 4           2016-15-13  1708748.37    1128242.43

# %% [markdown]
# Create a dataframe **`df3`** from the third sheet of the Excel file.
# * Note that you will need to skip the first few lines

# %%
# enter code here
data3 = pd.read_excel('/content/sample_sales.xlsx', sheet_name = 'Sample_Sales_3', skiprows= 4)
df3 = pd.DataFrame(data3)
df3.head()
# Out:
#                               Region     Country        Item Type  \
# 0       Middle East and North Africa  Azerbaijan  Office Supplies
# 1                             Europe     Romania        Cosmetics
# 2  Central America and the Caribbean   Nicaragua        Beverages
# 3                 Sub-Saharan Africa        Mali          Clothes
# 4                               Asia    Malaysia           Fruits
#
#   Order Priority Order Date  Total Cost  Total Profit
# 0              M 2012-06-13  1060944.16     255151.25
# 1              H 2010-11-26  2082940.30    1375311.70
# 2              C 2011-02-05   259279.24     127722.96
# 3              M 2011-07-26    31825.92      65214.72
# 4              L 2011-11-11    43367.64      15103.47

# %% [markdown]
# Create a dataframe **`df_concat_13`** that concatenates the dataframes **`df1`** and **`df3`** on the row axis.
#
# NB: remember to reset your index!

# %%
# enter code here

df_concat_13 = pd.concat([df1, df3], axis =0)
df_concat_13 = df_concat_13.reset_index()
df_concat_13
# Out:
#     index                             Region                Country  \
# 0       0                             Europe                 Russia
# 1       1              Australia and Oceania                 Tuvalu
# 2       2                                  ~  Sao Tome and Principe
# 3       3  Central America and the Caribbean                Grenada
# 4       4                             Europe                 Russia
# 5       5                 Sub-Saharan Africa  Sao Tome and Principe
# 6       6                 Sub-Saharan Africa                 Rwanda
# 7       7              Australia and Oceania        Solomon Islands
# 8       8                 Sub-Saharan Africa                 Angola
# 9       9                 Sub-Saharan Africa                 Angola
# 10     10                 Sub-Saharan Africa                      ~
# 11     11                 Sub-Saharan Africa  Republic of the Congo
# 12     12                 Sub-Saharan Africa                Senegal
# 13     13                               Asia             Kyrgyzstan
# 14     14                 Sub-Saharan Africa             Cape Verde
# 15     15                               Asia             Bangladesh
# 16     16                             Europe               Bulgaria
# 17     17  Central America and the Caribbean               Honduras
# 18     18                               Asia               Mongolia
# 19     19                             Europe               Bulgaria
# 20     20                               Asia              Sri Lanka
# 21     21                 Sub-Saharan Africa               Cameroon
# 22     22                               Asia           Turkmenistan
# 23     23              Australia and Oceania             East Timor
# 24     24                             Europe                 Norway
# 25     25                 Sub-Saharan Africa             The Gambia
# 26     26                             Europe               Portugal
# 27     27  Central America and the Caribbean               Honduras
# 28     28              Australia and Oceania            New Zealand
# 29     29                             Europe               Moldova
# 30     30                             Europe                 France
# 31     31              Australia and Oceania               Kiribati
# 32     32                 Sub-Saharan Africa                   Mali
# 33     33                             Europe                 Norway
# 34     34                 Sub-Saharan Africa             The Gambia
# 35     35                             Europe            Switzerland
# 36     36                 Sub-Saharan Africa            South Sudan
# 37     37              Australia and Oceania              Australia
# 38     38                               Asia                Myanmar
# 39     39                 Sub-Saharan Africa               Djibouti
# 40     40  Central America and the Caribbean             Costa Rica
# 41     41       Middle East and North Africa                  Syria
# 42     42                 Sub-Saharan Africa             The Gambia
# 43     43  Central America and the Caribbean             Costa Rica
# 44     44                               Asia                 Brunei
# 45     45                             Europe               Bulgaria
# 46     46                 Sub-Saharan Africa                  Niger
# 47     47       Middle East and North Africa             Azerbaijan
# 48     48                 Sub-Saharan Africa             The Gambia
# 49      0       Middle East and North Africa             Azerbaijan
# 50      1                             Europe                Romania
# 51      2  Central America and the Caribbean              Nicaragua
# 52      3                 Sub-Saharan Africa                   Mali
# 53      4                               Asia               Malaysia
# 54      5                 Sub-Saharan Africa           Sierra Leone
# 55      6                      North America                 Mexico
# 56      7                 Sub-Saharan Africa             Mozambique
#
#           Item Type Order Priority Order Date  Total Cost Total Profit
# 0   Office Supplies              L 2014-05-02   933903.84            ~
# 1         Baby Food              H 2010-05-28  1582243.50     951410.5
# 2            Fruits              C 2014-06-20    56065.84     19525.82
# 3            Cereal              C 2012-08-22   328376.44    248406.36
# 4   Office Supplies              L 2014-05-02   933903.84            ~
# 5            Fruits              C 2014-06-20    56065.84     19525.82
# 6   Office Supplies              L 2013-02-01  2657347.52     639077.5
# 7         Baby Food              C 2015-02-04   474115.08    285087.64
# 8         Household              M 2011-04-23  2104134.98            ~
# 9         Household              M 2011-04-23  2104134.98            ~
# 10       Vegetables              H 2012-07-17   734896.26    510216.66
# 11    Personal Care              M 2015-07-14   343986.90     152114.2
# 12           Cereal              H 2014-04-18   772106.23    584073.87
# 13       Vegetables              H 2011-06-24    11275.32            ~
# 14          Clothes              H 2014-08-02   149381.12    306097.92
# 15          Clothes              L 2017-01-13   296145.92    606834.72
# 16          Clothes              M 2012-04-23    59960.32    122865.12
# 17        Household              H 2017-02-08  4509793.96   1487261.02
# 18    Personal Care              C 2014-02-19   277739.67    122819.06
# 19          Clothes              M 2012-04-23    59960.32    122865.12
# 20        Cosmetics              M 2016-11-19  1830670.16   1208744.24
# 21        Beverages              C 2015-04-01   172619.70      85033.8
# 22        Household              L 2010-12-30  1924728.20     634745.9
# 23             Meat              L 2012-07-31  2154588.52     337937.6
# 24        Baby Food              L 2014-05-14  1187679.00       714157
# 25        Household              L 2012-05-26  1191019.80     392780.1
# 26        Baby Food              H 2015-07-31   202941.66    122029.78
# 27           Snacks              L 2016-06-30   216804.00     122686.5
# 28           Fruits              H 2014-09-08    15134.04      5270.67
# 29    Personal Care              L 2016-05-07   287316.90     127054.2
# 30        Cosmetics              H 2017-05-22   477943.95    315574.05
# 31           Fruits              M 2014-10-13    37354.16     13009.18
# 32           Fruits              L 2010-05-07    40288.24     14031.02
# 33        Beverages              C 2014-07-18   162891.96     80241.84
# 34        Household              L 2012-05-26  1191019.80     392780.1
# 35        Cosmetics              M 2012-09-17  2280701.13   1505888.07
# 36    Personal Care              C 2013-12-29   120423.75      53252.5
# 37  Office Supplies              C 2015-10-27  1534983.04       369155
# 38        Household              H 2015-01-16  4145955.00    1367272.5
# 39           Snacks              M 2017-02-25   713942.88    404010.78
# 40    Personal Care              L 2017-05-08   363198.03    160609.54
# 41           Fruits              L 2011-11-22    26185.28      9119.44
# 42             Meat              M 2017-01-14  1738477.23     272672.4
# 43    Personal Care              L 2017-05-08   363198.03    160609.54
# 44  Office Supplies              L 2012-04-01  3521431.68       846885
# 45  Office Supplies              M 2012-02-16  2093015.52    503358.75
# 46    Personal Care              H 2017-03-11   170860.05      75555.9
# 47        Cosmetics              M 2010-02-06  1904929.22   1257775.58
# 48           Cereal              H 2012-06-07   247921.87    187545.03
# 49  Office Supplies              M 2012-06-13  1060944.16    255151.25
# 50        Cosmetics              H 2010-11-26  2082940.30    1375311.7
# 51        Beverages              C 2011-02-05   259279.24    127722.96
# 52          Clothes              M 2011-07-26    31825.92     65214.72
# 53           Fruits              L 2011-11-11    43367.64     15103.47
# 54       Vegetables              C 2016-06-01   135031.05     93748.05
# 55    Personal Care              M 2015-07-30   326815.89    144521.02
# 56        Household              L 2012-02-10  2697132.18    889472.91

# %% [markdown]
# ## Replacing and removing

# %% [markdown]
# For dataframe **`df1`**, column name "Order Priority":
# * replace "H" with "High"
# * replace "M" with "Medium"
# * replace "L" with "Low"
#
# (Keep the dataframe name **`df1`**)

# %%
# Enter code here
df1['Order Priority'] = df1['Order Priority'].replace({'H':'High','M':'Medium','L':'Low'})
df1.head()
# Out:
#                               Region                Country        Item Type  \
# 0                             Europe                 Russia  Office Supplies
# 1              Australia and Oceania                 Tuvalu        Baby Food
# 2                                  ~  Sao Tome and Principe           Fruits
# 3  Central America and the Caribbean                Grenada           Cereal
# 4                             Europe                 Russia  Office Supplies
#
#   Order Priority Order Date  Total Cost Total Profit
# 0            Low 2014-05-02   933903.84            ~
# 1           High 2010-05-28  1582243.50     951410.5
# 2              C 2014-06-20    56065.84     19525.82
# 3              C 2012-08-22   328376.44    248406.36
# 4            Low 2014-05-02   933903.84            ~

# %% [markdown]
# For dataframe **`df1`**, replace all entries containing '~' with NaN values.
#
# NB: remember to import the numpy library!

# %%
# Enter code here
import numpy as np

df1 = df1.replace('~', np.nan)
df1.head()
# Out:
# /tmp/ipython-input-161-2646201687.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df1 = df1.replace('~', np.nan)
#                               Region                Country        Item Type  \
# 0                             Europe                 Russia  Office Supplies
# 1              Australia and Oceania                 Tuvalu        Baby Food
# 2                                NaN  Sao Tome and Principe           Fruits
# 3  Central America and the Caribbean                Grenada           Cereal
# 4                             Europe                 Russia  Office Supplies
#
#   Order Priority Order Date  Total Cost  Total Profit
# 0            Low 2014-05-02   933903.84           NaN
# 1           High 2010-05-28  1582243.50     951410.50
# 2              C 2014-06-20    56065.84      19525.82
# 3              C 2012-08-22   328376.44     248406.36
# 4            Low 2014-05-02   933903.84           NaN

# %% [markdown]
# For dataframe **`df1`**, remove all rows in the dataframe where there is a "C" in the "Order Priority" column
#
# NB: remember to reset your index!

# %%
# Enter code here
df1 = df1[df1['Order Priority'] != "C"].reset_index(drop=True)

df1
# Out:
#                                Region                Country        Item Type  \
# 0                              Europe                 Russia  Office Supplies
# 1               Australia and Oceania                 Tuvalu        Baby Food
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 4                  Sub-Saharan Africa                 Angola        Household
# 5                  Sub-Saharan Africa                 Angola        Household
# 6                  Sub-Saharan Africa                    NaN       Vegetables
# 7                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 8                  Sub-Saharan Africa                Senegal           Cereal
# 9                                Asia             Kyrgyzstan       Vegetables
# 10                 Sub-Saharan Africa             Cape Verde          Clothes
# 11                               Asia             Bangladesh          Clothes
# 12                             Europe               Bulgaria          Clothes
# 13  Central America and the Caribbean               Honduras        Household
# 14                             Europe               Bulgaria          Clothes
# 15                               Asia              Sri Lanka        Cosmetics
# 16                               Asia           Turkmenistan        Household
# 17              Australia and Oceania             East Timor             Meat
# 18                             Europe                 Norway        Baby Food
# 19                 Sub-Saharan Africa             The Gambia        Household
# 20                             Europe               Portugal        Baby Food
# 21  Central America and the Caribbean               Honduras           Snacks
# 22              Australia and Oceania            New Zealand           Fruits
# 23                             Europe               Moldova     Personal Care
# 24                             Europe                 France        Cosmetics
# 25              Australia and Oceania               Kiribati           Fruits
# 26                 Sub-Saharan Africa                   Mali           Fruits
# 27                 Sub-Saharan Africa             The Gambia        Household
# 28                             Europe            Switzerland        Cosmetics
# 29                               Asia                Myanmar        Household
# 30                 Sub-Saharan Africa               Djibouti           Snacks
# 31  Central America and the Caribbean             Costa Rica    Personal Care
# 32       Middle East and North Africa                  Syria           Fruits
# 33                 Sub-Saharan Africa             The Gambia             Meat
# 34  Central America and the Caribbean             Costa Rica    Personal Care
# 35                               Asia                 Brunei  Office Supplies
# 36                             Europe               Bulgaria  Office Supplies
# 37                 Sub-Saharan Africa                  Niger    Personal Care
# 38       Middle East and North Africa             Azerbaijan        Cosmetics
# 39                 Sub-Saharan Africa             The Gambia           Cereal
#
#    Order Priority Order Date  Total Cost  Total Profit
# 0             Low 2014-05-02   933903.84           NaN
# 1            High 2010-05-28  1582243.50     951410.50
# 2             Low 2014-05-02   933903.84           NaN
# 3             Low 2013-02-01  2657347.52     639077.50
# 4          Medium 2011-04-23  2104134.98           NaN
# 5          Medium 2011-04-23  2104134.98           NaN
# 6            High 2012-07-17   734896.26     510216.66
# 7          Medium 2015-07-14   343986.90     152114.20
# 8            High 2014-04-18   772106.23     584073.87
# 9            High 2011-06-24    11275.32           NaN
# 10           High 2014-08-02   149381.12     306097.92
# 11            Low 2017-01-13   296145.92     606834.72
# 12         Medium 2012-04-23    59960.32     122865.12
# 13           High 2017-02-08  4509793.96    1487261.02
# 14         Medium 2012-04-23    59960.32     122865.12
# 15         Medium 2016-11-19  1830670.16    1208744.24
# 16            Low 2010-12-30  1924728.20     634745.90
# 17            Low 2012-07-31  2154588.52     337937.60
# 18            Low 2014-05-14  1187679.00     714157.00
# 19            Low 2012-05-26  1191019.80     392780.10
# 20           High 2015-07-31   202941.66     122029.78
# 21            Low 2016-06-30   216804.00     122686.50
# 22           High 2014-09-08    15134.04       5270.67
# 23            Low 2016-05-07   287316.90     127054.20
# 24           High 2017-05-22   477943.95     315574.05
# 25         Medium 2014-10-13    37354.16      13009.18
# 26            Low 2010-05-07    40288.24      14031.02
# 27            Low 2012-05-26  1191019.80     392780.10
# 28         Medium 2012-09-17  2280701.13    1505888.07
# 29           High 2015-01-16  4145955.00    1367272.50
# 30         Medium 2017-02-25   713942.88     404010.78
# 31            Low 2017-05-08   363198.03     160609.54
# 32            Low 2011-11-22    26185.28       9119.44
# 33         Medium 2017-01-14  1738477.23     272672.40
# 34            Low 2017-05-08   363198.03     160609.54
# 35            Low 2012-04-01  3521431.68     846885.00
# 36         Medium 2012-02-16  2093015.52     503358.75
# 37           High 2017-03-11   170860.05      75555.90
# 38         Medium 2010-02-06  1904929.22    1257775.58
# 39           High 2012-06-07   247921.87     187545.03

# %% [markdown]
# Create a dataframe **`df_cereal`**. This dataframe should only contain the rows of **`df1`** where the "Item Type" entry is "Cereal"
# * remember to reset the index

# %%
# Enter code here
df_cereal = df1[df1["Item Type"] == "Cereal"].reset_index(drop=True)
df_cereal
# Out:
#                Region     Country Item Type Order Priority Order Date  \
# 0  Sub-Saharan Africa     Senegal    Cereal           High 2014-04-18
# 1  Sub-Saharan Africa  The Gambia    Cereal           High 2012-06-07
#
#    Total Cost  Total Profit
# 0   772106.23     584073.87
# 1   247921.87     187545.03

# %% [markdown]
# Remove the column "Total Cost" and "Total Profit" in dataframe **`df1`**.
#
# (Keep the dataframe name **`df1`**)

# %%
# Enter code here
df1 = df1.drop(["Total Cost","Total Profit"], axis =1)
df1
# Out:
#                                Region                Country        Item Type  \
# 0                              Europe                 Russia  Office Supplies
# 1               Australia and Oceania                 Tuvalu        Baby Food
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 4                  Sub-Saharan Africa                 Angola        Household
# 5                  Sub-Saharan Africa                 Angola        Household
# 6                  Sub-Saharan Africa                    NaN       Vegetables
# 7                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 8                  Sub-Saharan Africa                Senegal           Cereal
# 9                                Asia             Kyrgyzstan       Vegetables
# 10                 Sub-Saharan Africa             Cape Verde          Clothes
# 11                               Asia             Bangladesh          Clothes
# 12                             Europe               Bulgaria          Clothes
# 13  Central America and the Caribbean               Honduras        Household
# 14                             Europe               Bulgaria          Clothes
# 15                               Asia              Sri Lanka        Cosmetics
# 16                               Asia           Turkmenistan        Household
# 17              Australia and Oceania             East Timor             Meat
# 18                             Europe                 Norway        Baby Food
# 19                 Sub-Saharan Africa             The Gambia        Household
# 20                             Europe               Portugal        Baby Food
# 21  Central America and the Caribbean               Honduras           Snacks
# 22              Australia and Oceania            New Zealand           Fruits
# 23                             Europe               Moldova     Personal Care
# 24                             Europe                 France        Cosmetics
# 25              Australia and Oceania               Kiribati           Fruits
# 26                 Sub-Saharan Africa                   Mali           Fruits
# 27                 Sub-Saharan Africa             The Gambia        Household
# 28                             Europe            Switzerland        Cosmetics
# 29                               Asia                Myanmar        Household
# 30                 Sub-Saharan Africa               Djibouti           Snacks
# 31  Central America and the Caribbean             Costa Rica    Personal Care
# 32       Middle East and North Africa                  Syria           Fruits
# 33                 Sub-Saharan Africa             The Gambia             Meat
# 34  Central America and the Caribbean             Costa Rica    Personal Care
# 35                               Asia                 Brunei  Office Supplies
# 36                             Europe               Bulgaria  Office Supplies
# 37                 Sub-Saharan Africa                  Niger    Personal Care
# 38       Middle East and North Africa             Azerbaijan        Cosmetics
# 39                 Sub-Saharan Africa             The Gambia           Cereal
#
#    Order Priority Order Date
# 0             Low 2014-05-02
# 1            High 2010-05-28
# 2             Low 2014-05-02
# 3             Low 2013-02-01
# 4          Medium 2011-04-23
# 5          Medium 2011-04-23
# 6            High 2012-07-17
# 7          Medium 2015-07-14
# 8            High 2014-04-18
# 9            High 2011-06-24
# 10           High 2014-08-02
# 11            Low 2017-01-13
# 12         Medium 2012-04-23
# 13           High 2017-02-08
# 14         Medium 2012-04-23
# 15         Medium 2016-11-19
# 16            Low 2010-12-30
# 17            Low 2012-07-31
# 18            Low 2014-05-14
# 19            Low 2012-05-26
# 20           High 2015-07-31
# 21            Low 2016-06-30
# 22           High 2014-09-08
# 23            Low 2016-05-07
# 24           High 2017-05-22
# 25         Medium 2014-10-13
# 26            Low 2010-05-07
# 27            Low 2012-05-26
# 28         Medium 2012-09-17
# 29           High 2015-01-16
# 30         Medium 2017-02-25
# 31            Low 2017-05-08
# 32            Low 2011-11-22
# 33         Medium 2017-01-14
# 34            Low 2017-05-08
# 35            Low 2012-04-01
# 36         Medium 2012-02-16
# 37           High 2017-03-11
# 38         Medium 2010-02-06
# 39           High 2012-06-07

# %% [markdown]
# Some of the entries in **`df1`** are duplicates.
# If the same "Country" and "Item type" entries appear in more than one row, only keep the **`last`** entry and remove the rest of the duplicates. Keep the name of the dataframe **`df1`**
# * remember to reset the index

# %%
# Enter code here
df1 = df1.drop_duplicates(subset=['Country', 'Item Type'], keep='last').reset_index(drop=True)
df1
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1                              Europe                 Russia  Office Supplies
# 2                  Sub-Saharan Africa                 Rwanda  Office Supplies
# 3                  Sub-Saharan Africa                 Angola        Household
# 4                  Sub-Saharan Africa                    NaN       Vegetables
# 5                  Sub-Saharan Africa  Republic of the Congo    Personal Care
# 6                  Sub-Saharan Africa                Senegal           Cereal
# 7                                Asia             Kyrgyzstan       Vegetables
# 8                  Sub-Saharan Africa             Cape Verde          Clothes
# 9                                Asia             Bangladesh          Clothes
# 10  Central America and the Caribbean               Honduras        Household
# 11                             Europe               Bulgaria          Clothes
# 12                               Asia              Sri Lanka        Cosmetics
# 13                               Asia           Turkmenistan        Household
# 14              Australia and Oceania             East Timor             Meat
# 15                             Europe                 Norway        Baby Food
# 16                             Europe               Portugal        Baby Food
# 17  Central America and the Caribbean               Honduras           Snacks
# 18              Australia and Oceania            New Zealand           Fruits
# 19                             Europe               Moldova     Personal Care
# 20                             Europe                 France        Cosmetics
# 21              Australia and Oceania               Kiribati           Fruits
# 22                 Sub-Saharan Africa                   Mali           Fruits
# 23                 Sub-Saharan Africa             The Gambia        Household
# 24                             Europe            Switzerland        Cosmetics
# 25                               Asia                Myanmar        Household
# 26                 Sub-Saharan Africa               Djibouti           Snacks
# 27       Middle East and North Africa                  Syria           Fruits
# 28                 Sub-Saharan Africa             The Gambia             Meat
# 29  Central America and the Caribbean             Costa Rica    Personal Care
# 30                               Asia                 Brunei  Office Supplies
# 31                             Europe               Bulgaria  Office Supplies
# 32                 Sub-Saharan Africa                  Niger    Personal Care
# 33       Middle East and North Africa             Azerbaijan        Cosmetics
# 34                 Sub-Saharan Africa             The Gambia           Cereal
#
#    Order Priority Order Date
# 0            High 2010-05-28
# 1             Low 2014-05-02
# 2             Low 2013-02-01
# 3          Medium 2011-04-23
# 4            High 2012-07-17
# 5          Medium 2015-07-14
# 6            High 2014-04-18
# 7            High 2011-06-24
# 8            High 2014-08-02
# 9             Low 2017-01-13
# 10           High 2017-02-08
# 11         Medium 2012-04-23
# 12         Medium 2016-11-19
# 13            Low 2010-12-30
# 14            Low 2012-07-31
# 15            Low 2014-05-14
# 16           High 2015-07-31
# 17            Low 2016-06-30
# 18           High 2014-09-08
# 19            Low 2016-05-07
# 20           High 2017-05-22
# 21         Medium 2014-10-13
# 22            Low 2010-05-07
# 23            Low 2012-05-26
# 24         Medium 2012-09-17
# 25           High 2015-01-16
# 26         Medium 2017-02-25
# 27            Low 2011-11-22
# 28         Medium 2017-01-14
# 29            Low 2017-05-08
# 30            Low 2012-04-01
# 31         Medium 2012-02-16
# 32           High 2017-03-11
# 33         Medium 2010-02-06
# 34           High 2012-06-07

# %% [markdown]
# ## Dates

# %% [markdown]
# Consider dataframe **`df2`**.
# Change the Order Date column to a pandas datetime, with the format: year-month-day
#
# (Keep the dataframe name **`df2`**)
#
# * remember to add code that would allow for incorrect dates to be displayed as "NaT"

# %%
# Enter code here
df2['Order Date'] = pd.to_datetime(df2['Order Date'], format= '%Y-%m-%d', errors='coerce')
df2
# Out:
#                           Region                Country        Item Type  \
# 0                         Europe                 Monaco        Baby Food
# 1          Australia and Oceania                 Samoa         Cosmetics
# 2                         Europe                  Spain        Household
# 3   Middle East and North Africa                Lebanon          Clothes
# 4   Middle East and North Africa                   Iran        Cosmetics
# 5             Sub-Saharan Africa                 Zambia           Snacks
# 6             Sub-Saharan Africa                  Kenya       Vegetables
# 7                  North America                 Mexico    Personal Care
# 8             Sub-Saharan Africa  Sao Tome and Principe        Beverages
# 9             Sub-Saharan Africa             The Gambia        Baby Food
# 10  Middle East and North Africa                 Kuwait           Fruits
# 11                        Europe               Slovenia        Beverages
# 12            Sub-Saharan Africa           Sierra Leone  Office Supplies
# 13         Australia and Oceania              Australia        Beverages
#
#    Order Priority Order Date  Total Cost  Total Profit
# 0               H 2012-05-29  1373243.88     825738.04
# 1               H 2013-07-20  2542187.82    1678540.98
# 2               L 2012-10-21  2267963.02     747939.49
# 3               L        NaT   282562.56     579000.96
# 4               H        NaT  1708748.37    1128242.43
# 5               L 2011-01-04   398042.40     225246.90
# 6               L 2012-03-18   587135.01     407630.41
# 7               L 2012-02-17   363934.74     160935.32
# 8               C 2011-01-16   280673.91     138262.14
# 9               M 2014-02-03   886215.78     532885.74
# 10              M 2012-04-30     3612.24       1258.02
# 11              C 2016-10-23   148141.40      72975.60
# 12              H 2016-12-06   497662.08     119685.00
# 13              H 2014-07-07   298476.31     147031.74

# %% [markdown]
# Remove all the rows in **`df2`** that contain NaT values in your "Order Date" column.
#
# (Keep the dataframe name **df2**)
#
# * NB: since you removed some rows, remember to reset your index!

# %%
# Enter code here
df2 = df2[df2['Order Date'].notna()].reset_index(drop=True)
df2
# Out:
#                           Region                Country        Item Type  \
# 0                         Europe                 Monaco        Baby Food
# 1          Australia and Oceania                 Samoa         Cosmetics
# 2                         Europe                  Spain        Household
# 3             Sub-Saharan Africa                 Zambia           Snacks
# 4             Sub-Saharan Africa                  Kenya       Vegetables
# 5                  North America                 Mexico    Personal Care
# 6             Sub-Saharan Africa  Sao Tome and Principe        Beverages
# 7             Sub-Saharan Africa             The Gambia        Baby Food
# 8   Middle East and North Africa                 Kuwait           Fruits
# 9                         Europe               Slovenia        Beverages
# 10            Sub-Saharan Africa           Sierra Leone  Office Supplies
# 11         Australia and Oceania              Australia        Beverages
#
#    Order Priority Order Date  Total Cost  Total Profit
# 0               H 2012-05-29  1373243.88     825738.04
# 1               H 2013-07-20  2542187.82    1678540.98
# 2               L 2012-10-21  2267963.02     747939.49
# 3               L 2011-01-04   398042.40     225246.90
# 4               L 2012-03-18   587135.01     407630.41
# 5               L 2012-02-17   363934.74     160935.32
# 6               C 2011-01-16   280673.91     138262.14
# 7               M 2014-02-03   886215.78     532885.74
# 8               M 2012-04-30     3612.24       1258.02
# 9               C 2016-10-23   148141.40      72975.60
# 10              H 2016-12-06   497662.08     119685.00
# 11              H 2014-07-07   298476.31     147031.74

# %% [markdown]
# ## Dataframe --> CSV / Excel sheet

# %% [markdown]
# Write dataframe df1 to a csv named 'dataframe_1' and write it to your Drive

# %%
# Enter code here
from google.colab import drive
drive.mount('/content/drive')

df1.to_csv('/content/drive/My Drive/dataframe_1.csv', index=False)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Write dataframe df2 to an excel sheet named 'dataframe_2' and write it to your Drive

# %%
# Enter code here
df2.to_excel('/content/drive/My Drive/dataframe_2.xlsx', index=False)
